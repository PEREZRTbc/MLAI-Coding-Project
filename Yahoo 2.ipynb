# %%
import time
from yahoo_fin.stock_info import get_data
import requests
from bs4 import BeautifulSoup

# URL of the Wikipedia page containing the .wikitable
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table with class 'wikitable'
    table = soup.find('table', {'class': 'wikitable'})
    
    # Initialize an empty list to store symbols
    symbols = []
    
    # Find all table rows (tr) in the table
    rows = table.find_all('tr')
    
    # Loop through each row and extract symbol from the first cell (td)
    for row in rows:
        # Find the first table cell (td) in the row
        cell = row.find('td')
        
        # Check if cell is not None (i.e., a valid cell is found)
        if cell:
            # Extract text from the cell and strip any leading/trailing whitespace
            symbol = cell.get_text(strip=True)
            
            # Append the symbol to the symbols list (if not empty)
            if symbol:
                symbols.append(symbol)
    
    # Remove the header row symbol (if present)
    symbols = symbols[1:]

historical_datas = {}
for ticker in symbols:
    historical_datas[ticker] = get_data(ticker)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 45
#      43 historical_datas = {}
#      44 for ticker in symbols:
# ---> 45     historical_datas[ticker] = get_data(ticker)
#
# File ~\miniconda3\lib\site-packages\yahoo_fin\stock_info.py:90, in get_data(ticker, start_date, end_date, index_as_date, interval, headers)
#      86 resp = requests.get(site, params = params, headers = headers)
#      89 if not resp.ok:
# ---> 90     raise AssertionError(resp.json())
#      93 # get JSON response
#      94 data = resp.json()
#
# AssertionError: {'chart': {'result': None, 'error': {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}}}

# %%
import time
from yahoo_fin.stock_info import get_data
import requests
from bs4 import BeautifulSoup
import pandas

# URL of the Wikipedia page containing the .wikitable
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table with class 'wikitable'
    table = soup.find('table', {'class': 'wikitable'})
    
    # Initialize an empty list to store symbols
    symbols = []
    
    # Find all table rows (tr) in the table
    rows = table.find_all('tr')
    
    # Loop through each row and extract symbol from the first cell (td)
    for row in rows:
        # Find the first table cell (td) in the row
        cell = row.find('td')
        
        # Check if cell is not None (i.e., a valid cell is found)
        if cell:
            # Extract text from the cell and strip any leading/trailing whitespace
            symbol = cell.get_text(strip=True)
            
            # Append the symbol to the symbols list (if not empty)
            if symbol:
                symbols.append(symbol)
    
    # Remove the header row symbol (if present)
    symbols = symbols[1:]
df = pandas.DataFrame()

for ticker in symbols:
    df_temp = get_data(ticker, start_date = "1/01/2021", end_date = "1/01/2024", index_as_date = True, interval = "1wk")
# Out:
#                  open       high        low      close   adjclose    volume  \
# 2021-01-01  54.700001  56.970001  53.570000  56.830002  53.643536   4699600
# 2021-01-08  57.099998  58.970001  55.430000  57.419998  54.200443   4589000
# 2021-01-15  57.209999  58.430000  55.759998  58.040001  54.785686   4081300
# 2021-01-22  57.810001  60.450001  52.080002  56.910000  53.719040  11885100
# 2021-01-29  56.320000  58.779999  53.880001  58.639999  55.623932   7647900
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-01  75.470001  78.019997  75.190002  78.010002  77.704269   4811000
# 2023-12-08  78.120003  80.839996  77.660004  80.589996  80.274147   5275200
# 2023-12-15  79.730003  81.570000  78.860001  81.559998  81.240349   6162000
# 2023-12-22  81.949997  82.440002  81.239998  82.239998  81.917686   1764300
# 2023-12-29  82.029999  82.769997  82.029999  82.440002  82.116905    610900
#
#            ticker
# 2021-01-01    AOS
# ...

# %%
dfs = []

for ticker in symbols:
    print(ticker)
    df_temp = get_data(ticker, start_date="1/01/2021", end_date="1/01/2024", index_as_date=True, interval="1wk")
    dfs.append(df_temp)

df = pd.concat(dfs, ignore_index=True)
# Out:
# AOS
# ABT
# ABBV
# ACN
# ADBE
# AMD
# AES
# AFL
# A
# APD
# ABNB
# AKAM
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# AME
# AMGN
# APH
# ADI
# ANSS
# AON
# APA
# AAPL
# AMAT
# APTV
# ACGL
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# AXON
# BKR
# BALL
# BAC
# BK
# BBWI
# BAX
# BDX
# BRK.B
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 5
#       3 for ticker in symbols:
#       4     print(ticker)
# ----> 5     df_temp = get_data(ticker, start_date="1/01/2021", end_date="1/01/2024", index_as_date=True, interval="1wk")
#       6     dfs.append(df_temp)
#       8 df = pd.concat(dfs, ignore_index=True)
#
# File ~\miniconda3\lib\site-packages\yahoo_fin\stock_info.py:90, in get_data(ticker, start_date, end_date, index_as_date, interval, headers)
# ...

# %%
df = pandas.DataFrame()
errors = []

for ticker in symbols:
    try:
        df_temp = get_data(ticker, start_date="1/01/2021", end_date="1/01/2024", index_as_date=True, interval="1wk")
        df = df.append(df_temp)
    except AssertionError as e:
        errors.append((ticker, e))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26060\3062526655.py in ?()
#       5 errors = []
#       6
#       7 for ticker in symbols:
#       8     try:
# ----> 9         df_temp = get_data(ticker, start_date="1/01/2021", end_date="1/01/2024", index_as_date=True, interval="1wk")
#      10         df = df.append(df_temp)
#      11     except AssertionError as e:
#      12         errors.append((ticker, e))
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
